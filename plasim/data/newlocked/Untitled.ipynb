# %%
import numpy as np

# %%
f = open("plasim_snapshot","rb")
output = f.read()
f.close()

# %%
len(output)
# Out:
# 29300672

# %%
print output[0:100]
# Out:
#  M�'@
#   v�=yz%>�+�>�H�>?�3"?��C?��a?sw?�?�C

# %%
import struct

# %%
for n in range(1,9):
    print struct.unpack('i',output[4*n:4*(n+1)])
# Out:
# (333,)
# (0,)
# (10124,)
# (0,)
# (64,)
# (32,)
# (10,)
# (21,)

# %%
header = struct.unpack('8i',output[4:36])

# %%
zsig = struct.unpack('11f',output[36+8:36+8+11*4])

# %%
zsig
# Out:
# (0.07660000026226044,
#  0.1616000086069107,
#  0.26010000705718994,
#  0.3736000061035156,
#  0.5,
#  0.6336000561714172,
#  0.7651000022888184,
#  0.8815999627113342,
#  0.9665998816490173,
#  1.0,
#  360.0)

# %%
readn = 8236+2*4

# %%
head = struct.unpack('8i',output[readn:readn+8*4])

# %%
head
# Out:
# (129, 0, 10130, 210, 506, 1, 192, 360)

# %%
readn+=2*4

# %%
libd = {}

# %%
libd[str(head[0])] = np.array(struct.unpack('%df'%head[4],output[readn+8*4+8:readn+8*4+head[4]*4+8]))

# %%
libd["129"]
# Out:
# array([ 2.26939014e+03,  0.00000000e+00,  2.79302673e+02,  0.00000000e+00,
#         1.02335187e+03,  0.00000000e+00, -1.36163098e+03,  0.00000000e+00,
#         6.14964783e+02,  0.00000000e+00, -1.44860461e+03,  0.00000000e+00,
#         1.23269910e+03,  0.00000000e+00, -3.27985168e+02,  0.00000000e+00,
#         5.95126099e+02,  0.00000000e+00, -5.55712952e+02,  0.00000000e+00,
#        -8.33488083e+01,  0.00000000e+00, -3.58880676e+02,  0.00000000e+00,
#        -7.49920731e+01,  0.00000000e+00,  3.38924103e+02,  0.00000000e+00,
#        -7.32527695e+01,  0.00000000e+00,  1.37235336e+02,  0.00000000e+00,
#        -2.70319031e+02,  0.00000000e+00,  9.24720955e+00,  0.00000000e+00,
#        -4.66425934e+01,  0.00000000e+00,  7.72782059e+01,  0.00000000e+00,
#         9.87911377e+01,  0.00000000e+00, -7.49743881e+01,  0.00000000e+00,
#         4.69903198e+02, -5.01898560e+02, -9.29329216e-01, -4.19688080e+02,
# ...

# %%
readn+=8*4+head[4]*4+8*2

# %%
output[88:8236]
# Out:
# '\
# ...
